# %%
# coding: utf-8
# # 问题三
# ## [1. 读入数据](#1)
# ## [2. 处理数据](#2)
# ## [3. 线性回归预测](#3)

from sklearn import datasets
import matplotlib.pyplot as plt
from sklearn import linear_model
import pandas as pd
import math

# %%
seq = pd.read_csv('data.csv').loc[:, ['tNumber', 'time']]
data2 = pd.read_csv('risk1.csv')
data = pd.read_csv('score_z.csv')

al = []
for i in range(1, 93):
    al.append(60 * i - 1)

data['7'][50:60]
data2.info(verbose=True, null_counts=True)
d.info(verbose=True, null_counts=True)
need_fill = [7, 8, 9, 13, 20, 22, 24, 27, 28, 29, 35, 40, 41, 42, 43, 44, 45, 46, 47, 48, 50, 52, 55, 58, 67, 76, 77, 80, 83, 90, 98, 100]

i = '7'
j = 59
if math.isnan(d[i][j]):  # 空值，需要填充
    m = 1
    while(math.isnan(data[i][j - m])):
        m += 1
    d.loc[j, i] = data[i][j - m]
d[i][j]

# d.loc[i, j]#=data[i][j-m]

for i in need_fill:
    i = str(i)
    for j in al:
        if math.isnan(d[i][j]):  # 空值，需要填充
            m = 1
            while(math.isnan(data[i][j - m])):
                m += 1
            d.loc[j, i] = data[i][j - m]

# %%
from sklearn.svm import SVR

# 拟合回归模型
svr_rbf = SVR(kernel='rbf', C=100, gamma=0.1, epsilon=.1)
svr_lin = SVR(kernel='linear', C=100, gamma='auto')
svr_poly = SVR(kernel='poly', C=100, gamma='auto', degree=3, epsilon=.1, coef0=1)

# %%
# 查看结果
lw = 2
svrs = [svr_rbf, svr_lin, svr_poly]
kernel_label = ['RBF', 'Linear', 'Polynomial']
model_color = ['m', 'c', 'g']

fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(15, 10), sharey=True)
for ix, svr in enumerate(svrs):
    axes[ix].plot(X, svr.fit(X, y).predict(X), color=model_color[ix], lw=lw,
                   label='%s model' % kernel_label[ix])
    axes[ix].scatter(X[svr.support_], y[svr.support_], facecolor="none",
                     edgecolor=model_color[ix], s=50,
                     label='%s support vectors' % kernel_label[ix])
    axes[ix].scatter(X[np.setdiff1d(np.arange(len(X)), svr.support_)],
                     y[np.setdiff1d(np.arange(len(X)), svr.support_)],
                     facecolor="none", edgecolor="k", s=50,
                     label='other training data')
    axes[ix].legend(loc='upper center', bbox_to_anchor=(0.5, 1.1),
                     ncol=1, fancybox=True, shadow=True)
fig.text(0.5, 0.04, 'data', ha='center', va='center')
fig.text(0.06, 0.5, 'target', ha='center', va='center', rotation='vertical')
fig.suptitle("Support Vector Regression", fontsize=14)
plt.show()

# %%
from sklearn.svm import SVR
import matplotlib.pyplot as plt
import pandas as pd
import math
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
import numpy as np

# SVR models
svr_rbf = SVR(kernel='rbf', C=100, gamma=0.1, epsilon=.1)
svr_lin = SVR(kernel='linear', C=100, gamma='auto')
svr_poly = SVR(kernel='poly', C=100, gamma='auto', degree=2, epsilon=.1, coef0=1)
svrs = [svr_rbf, svr_lin, svr_poly]

# Polynomial regression
poly_reg = PolynomialFeatures(degree=3)
x_poly = poly_reg.fit_transform(X)
linear_reg = LinearRegression()
linear_reg.fit(x_poly, y)
plt.plot(X, y, 'b.')
plt.plot(X, linear_reg.predict(poly_reg.fit_transform(X)), 'r')
plt.show()

# Creating test data for linear regression
X_train = np.array(al[:45]).reshape(-1, 1)
X_test = np.array([5579, 5639, 5699]).reshape(-1, 1)
d2_pre = pd.DataFrame()
for i in range(1, 101):
    i_str = str(i)
    y_train = list(data2[i].values)
    poly_reg = PolynomialFeatures(degree=3)
    x_poly = poly_reg.fit_transform(X_train)
    linear_reg = LinearRegression()
    linear_reg.fit(x_poly, y_train)
    d2_pre[i_str] = linear_reg.predict(poly_reg.fit_transform(X_test))

# Creating DataFrame for linear regression prediction
d2_for = pd.DataFrame()
d2_for[5579] = (d2_pre.T[0] + d2_pre.T[1]) / 2
d2_for[5639] = d2_pre.T[1]
d2_for[5699] = (d2_pre.T[2] + d2_pre.T[1]) / 2
d2_for[5759] = d2_pre.T[2]

# Sorting DataFrame by column 5759
d2_for_sorted = d2_for.sort_values(by=5759)

# Description of DataFrame
d2_for.describe().T['mean'] * 100

# Transpose DataFrame
d2_for.T

# Plotting SVR with RBF kernel
plt.plot(X, y, 'b.')
plt.plot(X, svr_rbf.fit(X, y).predict(X), 'r')
plt.show()

# Plotting linear regression
linear_regressor = LinearRegression()
plt.plot(X, y, 'b.')
plt.plot(X, linear_regressor.fit(X, y).predict(X), 'r')
plt.show()

# Fitting linear regression model
linear_regressor = LinearRegression()
linear_regressor.fit(X_train, y_train)
y_predict_train = linear_regressor.predict(X_train)

# Fitting SVR polynomial model
y_pre = svr_poly.fit(X, y).predict(X)

# Creating data for linear regression
X = np.array(al[:45]).reshape(-1, 1)
X = X.reshape(-1, 1)
y = data2['10']

# Creating training data for linear regression
X_train = np.array(al[:45]).reshape(-1, 1)
X_train = X_train.reshape(-1, 1)
X_test = np.array([5579, 5639, 5699]).reshape(-1, 1)
X_test = X_test.reshape(-1, 1)
d2_pre = pd.DataFrame()
for i in range(1, 101):
    i_str = str(i)
    y_train = list(data2[i].values)
    linear_regressor = LinearRegression()
    linear_regressor.fit(X_train, y_train)
    d2_pre[i_str] = linear_regressor.predict(X_test)

# DataFrame
d2_pre

# Creating data for linear regression
X_train = np.array(d.index).reshape(-1, 1)
X_train = X_train.reshape(-1, 1)
X_test = np.array([5579, 5639, 5699, 5759]).reshape(-1, 1)
X_test = X_test.reshape(-1, 1)
d_pre = pd.DataFrame()
for i in range(1, 101):
    i_str = str(i)
    y_train = list(d[i].values)
    linear_regressor = LinearRegression()
    linear_regressor.fit(X_train, y_train)
    d_pre[i_str] = linear_regressor.predict(X_test)

# %% [markdown]
# Q4

# %%
al = []
for i in range(1, 49):
    al.append(120 * i - 1)

# Creating DataFrame d_30
d_30 = pd.DataFrame()
for i in al:
    if i < 5519:
        j = (i + 1) / 120 - 1
        d_30[i] = d.T[j]
    else:
        j = (i + 1) / 120 - 46
        d_30[i] = d2_pre.T[j]

# Displaying transposed DataFrame d_30
pd.set_option('display.max_rows', 10)
d_30.T

# Describing DataFrame d_30 and adding 'total' column
pd.set_option('display.max_columns', 10)
d_30t = d_30.T
d_30t['total'] = d_30.describe().T['mean'] * 100
d_30t

# Adding 'safe_score' column to DataFrame d_30t
d_30t['safe_score'] = finals
d_30t

# Calculating 'finals' values
mins = min(asrs.values)
maxs = max(asrs.values)
finals = 100 - ((asrs.values - mins) / (maxs - mins)) * 100

# Plotting scatter plot
plt.scatter(al, finals)
plt.show()
